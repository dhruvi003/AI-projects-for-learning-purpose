# %%
# !pip install langchain_community

# %%
# data ingestion
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("/content/speech.txt")

# %%
loader

# %%
text_doc = loader.load()

# %%
text_doc
# Out:
# [Document(metadata={'source': '/content/speech.txt'}, page_content='\n“My loving people,\n\nWe have been persuaded by some that are careful of our safety, to take heed how we commit our selves to armed multitudes, for fear of treachery; but I assure you I do not desire to live to distrust my faithful and loving people.\n\nLet tyrants fear. I have always so behaved myself that, under God, I have placed my chiefest strength and safeguard in the loyal hearts and good-will of my subjects; and therefore I am come amongst you, as you see, at this time, not for my recreation and disport, but being resolved, in the midst and heat of the battle, to live and die amongst you all; to lay down for my God, and for my kingdom, and my people, my honour and my blood, even in the dust.\n\nI know I have the body of a weak, feeble woman; but I have the heart and stomach of a king, and of a king of England too, and think foul scorn that Parma or Spain, or any prince of Europe, should dare to invade the b
# ...

# %%
# we will be using llms

# %%
# web based loader
from langchain_community.document_loaders import WebBaseLoader
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# !pip install beautifulsoup4

# %%
import bs4

# %%
# load chunk and index of html page

# %%
loader = WebBaseLoader(web_path=("https://lilianweng.github.io/posts/2023-06-23-agent/"), bs_kwargs=dict(parse_only=bs4.SoupStrainer(
    class_=("post-title","post_content","post_header")
)))

# %%
text_documents = loader.load()

# %%
text_documents[0]
# Out:
# Document(metadata={'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/'}, page_content='\n      LLM Powered Autonomous Agents\n    ')

# %%
# read completely from pdf

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader('/content/W15-1521.pdf')

# %%
a = loader.load()

# %%
# !pip install pypdf

# %%
a = loader.load()

# %%
a[0]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.3', 'creator': 'LaTeX with hyperref package', 'creationdate': '2015-05-18T00:58:32-07:00', 'author': 'Thang Luong ; Hieu Pham ; Christopher D. Manning', 'title': 'Bilingual Word Representations with Monolingual Quality in Mind', 'subject': 'VSM-NLP 2015', 'keywords': '', 'moddate': '2015-05-18T00:58:32-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX using libpoppler, Version 3.141592-1.40.3-2.2 (Web2C 7.5.6) kpathsea version 3.5.6', 'source': '/content/W15-1521.pdf', 'total_pages': 9, 'page': 0, 'page_label': '151'}, page_content='Proceedings of NAACL-HLT 2015, pages 151–159,\nDenver, Colorado, May 31 – June 5, 2015. c⃝2015 Association for Computational Linguistics\nBilingual Word Representations with Monolingual Quality i n Mind\nMinh-Thang Luong Hieu Pham Christopher D. Manning\nComputer Science Department, Stanford University, Stanfo rd, CA, 94305\n{lmthang, hyhieu, manning }@stanford.edu\nAbstract\nRecent work in learnin
# ...

# %%
#transforme -> we need to create chunks

# %%
# !pip install langchain

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_Splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

# %%
docs = text_Splitter.split_documents(a)

# %%
docs[:5]
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.3', 'creator': 'LaTeX with hyperref package', 'creationdate': '2015-05-18T00:58:32-07:00', 'author': 'Thang Luong ; Hieu Pham ; Christopher D. Manning', 'title': 'Bilingual Word Representations with Monolingual Quality in Mind', 'subject': 'VSM-NLP 2015', 'keywords': '', 'moddate': '2015-05-18T00:58:32-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX using libpoppler, Version 3.141592-1.40.3-2.2 (Web2C 7.5.6) kpathsea version 3.5.6', 'source': '/content/W15-1521.pdf', 'total_pages': 9, 'page': 0, 'page_label': '151'}, page_content='Proceedings of NAACL-HLT 2015, pages 151–159,\nDenver, Colorado, May 31 – June 5, 2015. c⃝2015 Association for Computational Linguistics\nBilingual Word Representations with Monolingual Quality i n Mind\nMinh-Thang Luong Hieu Pham Christopher D. Manning\nComputer Science Department, Stanford University, Stanfo rd, CA, 94305\n{lmthang, hyhieu, manning }@stanford.edu\nAbstract\nRecent work in learni
# ...

# %%
# vector embeddings and vector stores

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
from langchain_community.vectorstores import Chroma

# %%
# !pip install chromadb

# %%
db = Chroma.from_documents(docs[:20], OllamaEmbeddings())
# Out:
# /tmp/ipykernel_11286/482262721.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   db = Chroma.from_documents(docs[:20], OllamaEmbeddings())
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ...

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 60.5 MB/s eta 0:00:00
# ...

# %%
# vector database
query = "Who are the authors of this research paper"
